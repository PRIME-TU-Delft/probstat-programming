# %% [markdown]
# # Power Curves
#
# In this section we will be exploring power curves. We will start with an example in the situation of a z-test. That is, where we have known variance. Run the code below to get an example of a right-sided test.

# %%
import micropip

await micropip.install("ipywidgets")

# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interactive, fixed
from scipy import stats

# %%
def right_sided_ztest_power_curve(mu1_minus_mu0, sigma, n, alpha):
    plt.figure(figsize=(10, 6))
    
    for a in alpha:
        z_crit = stats.norm.ppf(1 - a)
        powers = []
        for d in mu1_minus_mu0:
            z_beta = (d * np.sqrt(n) / sigma) - z_crit
            power = stats.norm.cdf(z_beta)
            powers.append(power)
        
        plt.plot(mu1_minus_mu0, powers, label=f'Alpha = {a}')
    plt.xlabel('Effect Size')
    plt.ylabel('Power')
    plt.title('Power Curve for Right-Sided Z-Test')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

alpha = np.array([0.1,0.05,0.025,0.01,0.005])

n_vals = widgets.IntSlider(
    value=100, min=20, max=200, step=10, description="Max Sample Size"
)
sigma_vals = widgets.FloatSlider(
    value=2.55, min=0.1, max=5.0, step=0.1, description="Standard Deviation"
)
mu1_minus_mu0_vals = np.linspace(0, 2, 100)
interactive_plot = interactive(
    right_sided_ztest_power_curve,
    mu1_minus_mu0=fixed(mu1_minus_mu0_vals),
    sigma=sigma_vals,
    n=n_vals,
    alpha=fixed(alpha)
)
interactive_plot

# %% [markdown]
# Now run the code block below to plot the power curves for a left-sided test.

# %%
def left_sided_ztest_power_curve(mu1_minus_mu0, sigma, n, alpha):
    plt.figure(figsize=(10, 6))
    
    for a in alpha:
        z_crit = stats.norm.ppf(a)
        powers = []
        for d in mu1_minus_mu0:
            z_beta = z_crit - (d * np.sqrt(n) / sigma)
            power = stats.norm.cdf(z_beta)
            powers.append(power)
        
        plt.plot(mu1_minus_mu0, powers, label=f'Alpha = {a}')
    plt.xlabel('Effect Size')
    plt.ylabel('Power')
    plt.title('Power Curve for Left-Sided Z-Test')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

alpha = np.array([0.1,0.05,0.025,0.01,0.005])

n_vals = widgets.IntSlider(
    value=100, min=20, max=200, step=10, description="Max Sample Size"
)
sigma_vals = widgets.FloatSlider(
    value=2.55, min=0.1, max=5.0, step=0.1, description="Standard Deviation"
)
mu1_minus_mu0_vals = np.linspace(-2, 0.5, 100)
interactive_plot = interactive(
    left_sided_ztest_power_curve,
    mu1_minus_mu0=fixed(mu1_minus_mu0_vals),
    sigma=sigma_vals,
    n=n_vals,
    alpha=fixed(alpha)
)
interactive_plot

# %% [markdown]
# Finally, let's look at an example of a two-sided test. Run the code below.

# %%
def two_sided_ztest_power_curve(mu1_minus_mu0, sigma, n, alpha):
    plt.figure(figsize=(10, 6))
    
    for a in alpha:
        z_crit = stats.norm.ppf(1 - a/2)
        powers = []
        for d in mu1_minus_mu0:
            upper_power = (d * np.sqrt(n) / sigma) - z_crit
            lower_power = -1.0 * (d * np.sqrt(n) / sigma) - z_crit
            power = stats.norm.cdf(upper_power) + stats.norm.cdf(lower_power)
            powers.append(power)
        
        plt.plot(mu1_minus_mu0, powers, label=f'Alpha = {a}')
    plt.xlabel('Effect Size')
    plt.ylabel('Power')
    plt.title('Power Curve for Two-Sided Z-Test')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

alpha = np.array([0.1,0.05,0.025,0.01,0.005])

n_vals = widgets.IntSlider(
    value=100, min=20, max=200, step=10, description="Max Sample Size"
)
sigma_vals = widgets.FloatSlider(
    value=2.55, min=0.1, max=5.0, step=0.1, description="Standard Deviation"
)
mu1_minus_mu0_vals = np.linspace(-2, 2, 200)
interactive_plot = interactive(
    two_sided_ztest_power_curve,
    mu1_minus_mu0=fixed(mu1_minus_mu0_vals),
    sigma=sigma_vals,
    n=n_vals,
    alpha=fixed(alpha)
)
interactive_plot

# %% [markdown]
# ```{note}
# The z-test setting we are using in this example is relevant when we have a known population variance. In the setting where $\sigma$ is not known we will want to be using a t-test. When using the t-test we can estimate $\sigma$ using the sample standard deviation of a pre-sample or the sample itself.

# %% [markdown]
# Now let us move onto a different test. In this scenario we will be using a Poisson distribution and use the sum as the test statistic.
